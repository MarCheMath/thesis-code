# %%
import glob
import matplotlib
import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline

# %%
import utils
import metrics_utils
import metrics_utils_mod
#import sys
#sys.path.insert(0, '../src/')

import sparsity_mnist
# Out:
# toolz.functoolz
# toolz

# %%
matplotlib.rcParams.update({'font.size': 15})

# %%
is_save = True
figsize = metrics_utils.get_figsize(is_save)

# %% [markdown]
# # MNIST plots

# %% [markdown]
# ### Sensing images from the range of the generator

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
#    ('Lasso'  , '../estimated/mnist/full-input/gaussian/0.0/', '/lasso20/0.1'),
    ('Lasso switch'  , '../estimated/mnist/full-input/gaussian/0.0/', '/lasso20/0.0_sklearn-gs'),
#    ('Lasso fix 0.1'  , '../estimated/mnist/full-input/gaussian/0.0/', '/lasso20/0.1_sklearn'),
    ('TV norm'  , '../estimated/mnist/full-input/gaussian/0.0/', '/tvnorm20/tv-norm'),
    ('VAE'    , '../estimated/mnist/full-input/gaussian/For_VAE/', '/vae20/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('VAE+Reg', '../estimated/mnist/full-input/gaussian/For_VAE/', '/vae20/0.0_1.0_0.1_adam_0.1_0.9_False_1000_10')
]
save_path = '../results/mnist_reconstr_l2.pdf'


## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)


## Prettify
# axis
plt.gca().set_ylim(bottom=0)
plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([9, 800])

# labels, ticks, titles
ticks = [10, 25, 50, 100, 200, 300, 400, 500, 750]
labels = [10, 25, 50, 100, 200, 300, 400, 500, 750]
plt.xticks(ticks, labels, rotation=90)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legends
plt.legend(legends, fontsize=12.5)

# Saving
utils.save_plot(is_save, save_path)

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('Lasso'  , '../estimated/mnist/full-input/gaussian/0.0/', '/lasso20/*'),
    ('TV norm'  , '../estimated/mnist/full-input/gaussian/0.0/', '/tvnorm20/*'),
    ('VAE'    , '../estimated/mnist/full-input/gaussian/For_VAE/', '/vae20/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('VAE+Reg', '../estimated/mnist/full-input/gaussian/For_VAE/', '/vae20/0.0_1.0_0.1_adam_0.1_0.9_False_1000_10')
]
save_path = '../results/mnist_reconstr_l2.pdf'


## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)


## Prettify
# axis
plt.gca().set_ylim(bottom=0)
plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([9, 800])

# labels, ticks, titles
ticks = [10, 25, 50, 100, 200, 300, 400, 500, 750]
labels = [10, 25, 50, 100, 200, 300, 400, 500, 750]
plt.xticks(ticks, labels, rotation=90)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legends
plt.legend(legends, fontsize=12.5)

# Saving
utils.save_plot(is_save, save_path)

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('From VAE dim 5' , '../estimated/mnist/full-input/gaussian/0.0/',    '/vae5/0.0_1.0_0.1_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 20' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae20/0.0_1.0_0.1_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 40' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae40/0.0_1.0_0.1_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 60' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae60/0.0_1.0_0.1_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 80' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae80/0.0_1.0_0.1_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 100' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae100/0.0_1.0_0.1_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 175' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae175/0.0_1.0_0.1_adam_0.1_0.9_False_1000_10'),

]
save_path = '../results/mnist_gauss_meas_vaediff_zprior.pdf'


## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils_mod.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)


## Prettify

# axis
plt.gca().set_ylim([0,0.1])
plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([9, 800])

# labels, ticks, titles
ticks = [10, 25, 50, 100, 200, 300, 400, 500, 750]
labels = [10, 25, 50, 100, 200, 300, 400, 500, 750]
plt.xticks(ticks, labels, rotation=90)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legend
plt.legend(legends, fontsize=12.5)

# Saving
utils.save_plot(is_save, save_path)

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('From VAE dim 5' , '../estimated/mnist/full-input/gaussian/0.0/',    '/vae5/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 20' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae20/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 40' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae40/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 60' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae60/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 80' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae80/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 100' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 175' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae175/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('Lasso'  , '../estimated/mnist/full-input/gaussian/0.0/', '/lasso20/*'),
]
save_path = '../results/mnist_gauss_meas_vaediff_withlasso.pdf'


## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils_mod.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)


## Prettify

# axis
plt.gca().set_ylim(bottom=0)
#plt.gca().set_ylim(bottom=0,top=0.02)

plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([9, 800])

# labels, ticks, titles
ticks = [10, 25, 50, 100, 200, 300, 400, 500, 750]
labels = [10, 25, 50, 100, 200, 300, 400, 500, 750]
plt.xticks(ticks, labels, rotation=90)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legend
plt.legend(legends, fontsize=12.5)

# Saving
utils.save_plot(is_save, save_path)

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('From VAE dim 5' , '../estimated/mnist/full-input/gaussian/0.0/',    '/vae-flex-5/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 20' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae-flex-20/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 40' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae-flex-40/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 60' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae-flex-60/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 80' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae-flex-80/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 100' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae-flex-100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 175' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae175/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('Lasso'  , '../estimated/mnist/full-input/gaussian/0.0/', '/lasso20/*'),
]
save_path = '../results/mnist_gauss_meas_vaediff_withlasso_FORFLEX.pdf'


## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils_mod.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)


## Prettify

# axis
plt.gca().set_ylim(bottom=0)
#plt.gca().set_ylim(bottom=0,top=0.02)

plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([9, 800])

# labels, ticks, titles
ticks = [10, 25, 50, 100, 200, 300, 400, 500, 750]
labels = [10, 25, 50, 100, 200, 300, 400, 500, 750]
plt.xticks(ticks, labels, rotation=90)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legend
plt.legend(legends, fontsize=12.5)

# Saving
utils.save_plot(is_save, save_path)

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('From VAE dim 5' , '../estimated/mnist/full-input/gaussian/0.0/',    '/vae5/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 40' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae40/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 20' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae20/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 60' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae60/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 80' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae80/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 100' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 175' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae175/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),

]
save_path = '../results/mnist_gauss_meas_vaediff_100plus.pdf'


## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils_mod.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)


## Prettify

# axis
#plt.gca().set_ylim(bottom=0)
plt.gca().set_ylim([0,0.02])
#plt.gca().set_ylim(bottom=0,top=0.02)

#plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([100,800])

# labels, ticks, titles
ticks = [100, 200, 300, 400, 500, 750]
labels = [100, 200, 300, 400, 500, 750]
plt.xticks(ticks, labels, rotation=90)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legend
plt.legend(legends, fontsize=12.5)

# Saving
utils.save_plot(is_save, save_path)

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('From VAE dim 5' , '../estimated/mnist/full-input/gaussian/0.0/',    '/vae5/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 40' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae40/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 20' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae20/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 80' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae80/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 100' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE flex' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflexgrid100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10_0.01"),
#    ('From VAE flex' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflex100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10_0.01_5_random"),
    ('From VAE flex' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflex100/0.0_1.0_0.0_adam_0.1_0.9_False_1001_10_0.01_1_previous-and-random"),
#    ('From VAE flex' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflexalt100/0.0_1.0_0.0_adam_0.1_0.9_False_1001_10_0.01_1_previous-and-random"),
#    ('Lasso'  , '../estimated/mnist/full-input/gaussian/0.0/', '/lasso20/*'),
#    ('TV norm'  , '../estimated/mnist/full-input/gaussian/0.0/', '/tvnorm20/*'),
]
save_path = '../results/mnist_gauss_meas_vae_flexII_withlasso.pdf'


## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils_mod.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)


## Prettify

# axis
plt.gca().set_ylim(bottom=0)
#plt.gca().set_ylim([0,0.005])
#plt.gca().set_ylim(bottom=0,top=0.02)

plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([9, 800])

# labels, ticks, titles
ticks = [10, 25, 50, 100, 200, 300, 400, 500, 750]
labels = [10, 25, 50, 100, 200, 300, 400, 500, 750]
plt.xticks(ticks, labels, rotation=90)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legend
plt.legend(legends, fontsize=12.5)

# Saving
#utils.save_plot(is_save, save_path)

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('From VAE dim 5' , '../estimated/mnist/full-input/gaussian/0.0/',    '/vae5/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 40' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae40/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 20' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae20/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('From VAE dim 80' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae80/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 100' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE flex' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflexgrid100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10_0.01"),
#    ('From VAE flex' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflex100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10_0.01_5_random"),
#    ('From VAE flex OLD' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflex100/0.0_1.0_0.0_adam_0.1_0.9_False_1001_10_0.01_1_previous-and-random"),
    ('From VAE flex ' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflex5-10-15-20-40-60-80-100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10_0.01_1_previous-and-random_flexible"),
    ('From VAE flex alt' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflexalt100/0.0_1.0_0.0_adam_0.01_0.9_False_1000_10_0.01_1_previous-and-random_flexible"),    
    ('Lasso'  , '../estimated/mnist/full-input/gaussian/0.0/', '/lasso20/*'),
    ('TV norm'  , '../estimated/mnist/full-input/gaussian/0.0/', '/tvnorm20/*'),
    ('TV norm reweight'  , '../estimated/mnist/full-input/gaussian/0.0/', '/tvnorm/0.0_cvxpy-constr-reweight*'),
]
save_path = '../results/mnist_gauss_meas_vae_flexII_otherflex_withlassotv.pdf'


## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils_mod.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)
    
#plt.plot([0.075625  , 0.03317602,0.03317602, 0.00895727, 0.00050625,])
## Prettify

# axis
plt.gca().set_ylim(bottom=0)
#plt.gca().set_ylim([0,0.005])
#plt.gca().set_ylim(bottom=0,top=0.02)

plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([9, 800])

# labels, ticks, titles
ticks = [10, 25, 50, 100, 200, 300, 400, 500, 750]
labels = [10, 25, 50, 100, 200, 300, 400, 500, 750]
plt.xticks(ticks, labels, rotation=90)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legend
plt.legend(legends, fontsize=12.5)

# Saving
#utils.save_plot(is_save, save_path)

# %%
import numpy as np
e = np.zeros(5)
a = np.load('../estimated/mnist/full-input/gaussian/0.0/10/vaeflexalt100/0.0_1.0_0.0_adam_0.01_0.9_False_1000_10_0.01_1_previous-and-random_flexible/l2_losses.pkl')
e[0] = np.sqrt(a[0]*784)
a = np.load('../estimated/mnist/full-input/gaussian/0.0/50/vaeflexalt100/0.0_1.0_0.0_adam_0.01_0.9_False_1000_10_0.01_1_previous-and-random_flexible/l2_losses.pkl')
e[1] = np.sqrt(a[0]*784)
a = np.load('../estimated/mnist/full-input/gaussian/0.0/100/vaeflexalt100/0.0_1.0_0.0_adam_0.01_0.9_False_1000_10_0.01_1_previous-and-random_flexible/l2_losses.pkl')
e[2] = np.sqrt(a[0]*784)
a = np.load('../estimated/mnist/full-input/gaussian/0.0/200/vaeflexalt100/0.0_1.0_0.0_adam_0.01_0.9_False_1000_10_0.01_1_previous-and-random_flexible/l2_losses.pkl')
e[3] = np.sqrt(a[0]*784)
a = np.load('../estimated/mnist/full-input/gaussian/0.0/300/vaeflexalt100/0.0_1.0_0.0_adam_0.01_0.9_False_1000_10_0.01_1_previous-and-random_flexible/l2_losses.pkl')
e[4] = np.sqrt(a[0]*784)
e
# Out:
# array([1.986072  , 1.02187736, 0.88556235, 0.83895788, 0.80029876])

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('Measurement 10' , '../estimated/mnist/full-input/gaussian/0.0/10/',    '/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('Measurement 25' , '../estimated/mnist/full-input/gaussian/0.0/25/',    '/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('Measurement 50' , '../estimated/mnist/full-input/gaussian/0.0/50/',    '/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('Measurement 100' , '../estimated/mnist/full-input/gaussian/0.0/100/',    '/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('Measurement 200' , '../estimated/mnist/full-input/gaussian/0.0/200/',    '/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('Measurement 300' , '../estimated/mnist/full-input/gaussian/0.0/300/',    '/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('Measurement 400' , '../estimated/mnist/full-input/gaussian/0.0/400/',    '/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('Measurement 500' , '../estimated/mnist/full-input/gaussian/0.0/500/',    '/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('Measurement 600' , '../estimated/mnist/full-input/gaussian/0.0/600/',    '/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
    ('Measurement 750' , '../estimated/mnist/full-input/gaussian/0.0/750/',    '/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),

#    ('From VAE dim 40' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae40/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 20' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae20/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 80' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae80/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE dim 100' , '../estimated/mnist/full-input/gaussian/0.0/' ,    '/vae100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10'),
#    ('From VAE flex' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflexgrid100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10_0.01"),
#    ('From VAE flex' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflex100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10_0.01_5_random"),
#    ('From VAE flex' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflex100/0.0_1.0_0.0_adam_0.1_0.9_False_1001_10_0.01_1_previous-and-random"),
 #   ('From VAE flex' , '../estimated/mnist/full-input/gaussian/0.0/' ,    "/vaeflex5-10-15-20-40-60-80-100/0.0_1.0_0.0_adam_0.1_0.9_False_1000_10_0.01_1_previous-and-random_flexible"),
  #  ('Lasso'  , '../estimated/mnist/full-input/gaussian/0.0/', '/lasso20/*'),
  #  ('TV norm'  , '../estimated/mnist/full-input/gaussian/0.0/', '/tvnorm20/*'),
]
save_path = '../results/mnist_gauss_meas_vae_ordered_measurement.pdf'


## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils_mod.plot(base, regex, criterion, retrieve_list,name='vae')
    legends.append(legend)


## Prettify

# axis
plt.gca().set_ylim(bottom=0)
#plt.gca().set_ylim([0,0.005])
#plt.gca().set_ylim(bottom=0,top=0.02)

plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([9, 800])

# labels, ticks, titles
ticks = [10, 25, 50, 100, 200, 300, 400, 500, 750]
labels = [10, 25, 50, 100, 200, 300, 400, 500, 750]
plt.xticks(ticks, labels, rotation=90)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legend
plt.legend(legends, fontsize=12.5)

# Saving
#utils.save_plot(is_save, save_path)
# Out:
# ['vae10', 'vae20NoGrid', 'vae5', 'vae20', 'vaeflex100', 'vaeflexgrid100', 'vae80', 'vae150', 'vae100', 'vae40', 'vae125', 'vaeflex5-10-15-20-40-60-80-100', 'vae-flex[100]', 'vae60', 'vae20[]', 'vae175']
# ['10', '20', '5', '20', '80', '150', '100', '40', '125', '60', '20', '175']
# ['vae10', 'vae20NoGrid', 'vaeflex5-10-20-40-60-80-100', 'vae5', 'vae20', 'vaeflex100', 'vaeflexgrid100', 'vae80', 'vae150', 'vae100', 'vae40', 'vae125', 'vaeflex5-10-15-20-40-60-80-100', 'vae-flex[100]', 'vae60', 'vae175']
# ['10', '20', '5', '20', '80', '150', '100', '40', '125', '60', '175']
# ['vae10', 'vae20NoGrid', 'vae5', 'vae20', 'vaeflex100', 'vaeflexgrid100', 'vae80', 'vae150', 'vae100', 'vae40', 'vae125', 'vaeflex5-10-15-20-40-60-80-100', 'vae-flex[100]', 'vae60', 'vae175']
# ['10', '20', '5', '20', '80', '150', '100', '40', '125', '60', '175']
# ...

# %% [markdown]
# ### Noise tolerance

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('Lasso, m=500' , '../estimated/mnist/full-input/gaussian/', '/500/lasso/0.1'),
    ('VAE, m=100'   , '../estimated/mnist/full-input/gaussian/', '/100/vae/0.0_1.0_0.1_adam_0.01_0.9_False_1000_2'),
    ('VAE, m=500'   , '../estimated/mnist/full-input/gaussian/', '/500/vae/0.0_1.0_0.1_adam_0.01_0.9_False_1000_2'),
]
save_path = '../results/mnist_noise_l2.pdf'


## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)
    

## Prettify

# axis
plt.gca().set_ylim(bottom=0)
plt.gca().set_xscale("log", nonposx='clip')

# labels, ticks, titles
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Standard deviation of noise')

# Legend
plt.legend(legends, fontsize=12.5, loc=2)

# Saving
utils.save_plot(is_save, save_path)

# %% [markdown]
# ### Compare hyperparamter settings

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
base, tail = '../estimated/mnist/full-input/gaussian/0.1/', '/vae/'
other_hparams = set([a.split('/')[-1] for a in glob.glob(base + '*' + tail + '*')])
legend_base_regexs = []
for hparam in other_hparams:
    legend_base_regexs.append((hparam, base, tail + hparam))

## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)


## Prettify

# axis
plt.gca().set_ylim(bottom=0)
plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([9.5, 510])

# labels, ticks, titles
ticks = [10, 25, 50, 100, 200, 300, 400, 500]
labels = [10, 25, 50, 100, 200, 300, 400, 500]
plt.xticks(ticks, labels, rotation=90)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legend
plt.legend(legends, fontsize=8)

# %% [markdown]
# # celebA plots

# %% [markdown]
# ### Recontruction from gaussian measurements

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('Lasso (DCT)'     , '../estimated/celebA/full-input/gaussian/0.01/', '/lasso-dct/*'),
    ('Lasso (Wavelet)' , '../estimated/celebA/full-input/gaussian/0.01/', '/lasso-wavelet/1e-05'),
    ('DCGAN'           , '../estimated/celebA/full-input/gaussian/0.01/', '/dcgan/0.0_1.0_0.0_0.0_0.0_adam_0.1_0.9_False_500_2'),
    ('DCGAN+Reg'       , '../estimated/celebA/full-input/gaussian/0.01/', '/dcgan/0.0_1.0_0.001_0.0_0.0_adam_0.1_0.9_False_500_10'),
]
save_path = '../results/celebA_reconstr_l2.pdf'

## Plot
figsize=[6, 4.05]
# figsize=[12, 8.1]
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)
    

## Prettify
# axis
plt.gca().set_ylim(bottom=0)
plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([19, 11000])

# labels, ticks, titles
ticks = [20, 50, 100, 200, 500, 1000, 2500, 5000, 7500, 10000]
labels = [20, 50, 100, 200, 500, 1000, 2500, 5000, 7500, 10000]
plt.xticks(ticks, labels, rotation=90)
plt.xticks(ticks, labels)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legends
# plt.legend(legends, fontsize=12.5)
plt.legend(legends, fontsize=8)

# Saving
utils.save_plot(is_save, save_path)

# %% [markdown]
# ### Sensing images from the span of the generator

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('From test set' , '../estimated/celebA/full-input/gaussian/0.01/', '/dcgan/0.0_1.0_0.001_0.0_0.0_adam_0.1_0.9_False_500_10'),
    ('From generator', '../estimated/celebA/gen-span/gaussian/0.01/'  , '/dcgan/0.0_1.0_0.001_0.0_0.0_adam_0.1_0.9_False_500_1'),
]
save_path = '../results/celebA_gen_range.pdf'

    
## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)
    

## Prettify
# axis
plt.gca().set_ylim(bottom=0)
plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([19, 2600])

# labels, ticks, titles
ticks = [20, 50, 100, 200, 500, 1000, 2500]
labels = [20, 50, 100, 200, 500, 1000, 2500]
plt.xticks(ticks, labels, rotation=90)
plt.xticks(ticks, labels)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legends
plt.legend(legends, fontsize=12.5)

# Saving
utils.save_plot(is_save, save_path)

# %% [markdown]
# ### Noise tolerance

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('Lasso (DCT), m=2500'     , '../estimated/celebA/full-input/gaussian/', '/2500/lasso-dct/*'),
    ('Lasso (Wavelet), m=2500' , '../estimated/celebA/full-input/gaussian/', '/2500/lasso-wavelet/0.1'),
    ('DCGAN, m=2500' , '../estimated/celebA/full-input/gaussian/', '/2500/dcgan/0.0_1.0_0.001_0.0_0.0_adam_0.1_0.9_False_5000_1'),
]
save_path = '../results/celebA_noise_l2.pdf'

## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils.plot(base, regex, criterion, retrieve_list)
    legends.append(legend) 
    

## Prettify

# axis
plt.gca().set_ylim(bottom=0)
plt.gca().set_xscale("log", nonposx='clip')

# labels, ticks, titles
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Standard deviation of noise')

# Legend
plt.legend(legends, fontsize=12.5, loc=2)

# Saving
utils.save_plot(is_save, save_path)

# %% [markdown]
# ## k-sparse-wavelet

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
legend_base_regexs = [
    ('k-sparse-wavelet, m=12288' , '../estimated/celebA/full-input/project/0.0/12288/k-sparse-wavelet/', '')
]
# save_path = '../results/celebA_noise_l2.pdf'

## Plot
plt.figure(figsize=[12, 8])
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils.plot(base, regex, criterion, retrieve_list)
    legends.append(legend) 
    

## Prettify

# axis
plt.gca().set_ylim(bottom=0)
plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([40, 13000])

# labels, ticks, titles
ticks = [50, 100, 200, 500, 1000, 2500, 5000, 7500, 10000, 12288]
labels = [50, 100, 200, 500, 1000, 2500, 5000, 7500, 10000, 12288]
plt.xticks(ticks, labels, rotation=90)
plt.xticks(ticks, labels)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('k')

# Legend
plt.legend(legends, fontsize=12.5, loc=1)

# # Saving
# utils.save_plot(is_save, save_path)

# %% [markdown]
# ### Compare hyperparameter settings

# %%
## Define what to plot
criterion = ['l2', 'mean']
retrieve_list = [['l2', 'mean'], ['l2', 'std']]
base, tail = '../estimated/celebA/full-input/gaussian/0.01/', '/dcgan/'
other_hparams = set([a.split('/')[-1] for a in glob.glob(base + '*' + tail + '*')])
legend_base_regexs = []
for hparam in other_hparams:
    legend_base_regexs.append((hparam, base, tail + hparam))


## Plot
plt.figure(figsize=figsize)
legends = []
for legend, base, regex in legend_base_regexs:
    metrics_utils.plot(base, regex, criterion, retrieve_list)
    legends.append(legend)
    

## Prettify
# axis
plt.gca().set_ylim(bottom=0)
plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_xlim([19, 11000])

# # labels, ticks, titles
ticks = [20, 50, 100, 200, 500, 1000, 2500, 5000, 7500, 10000]
labels = [20, 50, 100, 200, 500, 1000, 2500, 5000, 7500, 10000]
plt.xticks(ticks, labels, rotation=90)
plt.xticks(ticks, labels)
plt.ylabel('Reconstruction error (per pixel)')
plt.xlabel('Number of measurements')

# Legends
plt.legend(legends, fontsize=8)
